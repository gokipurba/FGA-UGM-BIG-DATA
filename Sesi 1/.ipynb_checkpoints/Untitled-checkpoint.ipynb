# %%
import pandas as pd

# %%
df  = pd.read_csv("classification_5000.csv")
df
# Out:
#               DateTime  In_Flow  In_Angle  In_Temp  Out_Temp  In_Pressure  \
# 0     2021-01-01 00:00     1.41      0.40     0.27     -0.31         1.75
# 1     2021-01-01 01:00    -1.41     -0.02    -0.52     -1.83        -3.13
# 2     2021-01-01 02:00     0.29      0.67    -0.36     -0.01        -1.93
# 3     2021-01-01 03:00     2.98      1.00    -1.19     -0.80         1.72
# 4     2021-01-01 04:00     0.27      1.92    -0.37      0.16         0.95
# ...                ...      ...       ...      ...       ...          ...
# 4995  2021-07-27 03:00     0.22     -0.42     0.56     -0.97         1.40
# 4996  2021-07-27 04:00     0.87     -1.54     1.78     -0.64         1.04
# 4997  2021-07-27 05:00     0.17     -0.75     0.46      0.33         1.05
# 4998  2021-07-27 06:00     0.73      0.40     1.51     -1.50        -2.33
# 4999  2021-07-27 07:00    -0.05     -0.73     0.29      1.62         1.43
#
#       Viscosity  Humidity  Rot_Speed  Valve_Opening  Tank_%  Out_Speed  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DateTime       5000 non-null   object
#  1   In_Flow        5000 non-null   float64
#  2   In_Angle       5000 non-null   float64
#  3   In_Temp        5000 non-null   float64
#  4   Out_Temp       5000 non-null   float64
#  5   In_Pressure    5000 non-null   float64
#  6   Viscosity      5000 non-null   float64
#  7   Humidity       5000 non-null   float64
#  8   Rot_Speed      5000 non-null   float64
#  9   Valve_Opening  5000 non-null   float64
#  10  Tank_%         5000 non-null   float64
#  11  Out_Speed      5000 non-null   float64
#  12  Thickness      5000 non-null   float64
#  13  Vibration      5000 non-null   float64
#  14  Col_density    5000 non-null   float64
#  15  Oxygen         5000 non-null   float64
#  16  Quality_type   5000 non-null   object
# ...

# %%
df.describe()
# Out:
#            In_Flow     In_Angle      In_Temp     Out_Temp  In_Pressure  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.678662    -0.014500     0.015068    -0.325204     0.321296
# std       1.399886     1.000462     1.001892     1.624843     1.513627
# min      -6.100000    -4.260000    -3.490000    -5.870000    -5.160000
# 25%      -0.060000    -0.700000    -0.680000    -1.460000    -0.640000
# 50%       0.820000    -0.020000     0.020000    -0.450000     0.500000
# 75%       1.580000     0.670000     0.720000     0.690000     1.380000
# max       5.080000     3.310000     3.500000     5.810000     4.900000
#
#          Viscosity     Humidity    Rot_Speed  Valve_Opening       Tank_%  \
# count  5000.000000  5000.000000  5000.000000    5000.000000  5000.000000
# mean      0.016494     0.602450    -0.041896       0.001114     0.003056
# std       0.991784     1.354942     2.049810       1.005592     1.550016
# ...

# %%
df.corr()
# Out:
#                 In_Flow  In_Angle   In_Temp  Out_Temp  In_Pressure  Viscosity  \
# In_Flow        1.000000 -0.003215 -0.013636  0.052537     0.225834  -0.005518
# In_Angle      -0.003215  1.000000 -0.021197 -0.011058     0.020030   0.011512
# In_Temp       -0.013636 -0.021197  1.000000  0.017025    -0.005671  -0.004853
# Out_Temp       0.052537 -0.011058  0.017025  1.000000     0.335845   0.015195
# In_Pressure    0.225834  0.020030 -0.005671  0.335845     1.000000   0.014567
# Viscosity     -0.005518  0.011512 -0.004853  0.015195     0.014567   1.000000
# Humidity       0.577518  0.012110 -0.018469  0.052069     0.359416  -0.005198
# Rot_Speed      0.563143 -0.020147  0.008818  0.595381     0.199894   0.009250
# Valve_Opening -0.020819 -0.013598 -0.020885 -0.012813    -0.009023  -0.011055
# Tank_%        -0.107559  0.004809 -0.012042  0.019571     0.033507  -0.002515
# Out_Speed      0.005053  0.004233 -0.002168 -0.014401    -0.002565  -0.008765
# ...

# %%
dfc19 = pd.read_excel("kasuscovid19.xlsx")
dfc19
# Out:
#     Total Kasus   Bali  Banten  Babel  Bengkulu     DIY  Jakarta  Jambi  \
# 0    2020-03-18      1      17      0         0       3      158      0
# 1    2020-03-19      1      27      0         0       5      210      0
# 2    2020-03-20      4      37      0         0       4      215      0
# 3    2020-03-21      3      43      0         0       5      267      0
# 4    2020-03-22      3      47      0         0       5      307      0
# ..          ...    ...     ...    ...       ...     ...      ...    ...
# 511  2021-08-11  89898  122542  40027     20705  133411   835609  23792
# 512  2021-08-12  91251  122937  40422     20822  134494   836687  23892
# 513  2021-08-13  93161  123650  41082     21019  135737   837897  24292
# 514  2021-08-14  94956  124255  41635     21284  137525   839260  24706
# 515  2021-08-15  96027  124661  41946     21361  138458   840442  25082
#
#       Jabar  Jateng  ...  Maluku  Papbar  Papua  Sulbar    NTT  Gorontalo  \
# ...

# %%
dfc19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 38 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Total Kasus  516 non-null    datetime64[ns]
#  1   Bali         516 non-null    int64
#  2   Banten       516 non-null    int64
#  3   Babel        516 non-null    int64
#  4   Bengkulu     516 non-null    int64
#  5   DIY          516 non-null    int64
#  6   Jakarta      516 non-null    int64
#  7   Jambi        516 non-null    int64
#  8   Jabar        516 non-null    int64
#  9   Jateng       516 non-null    int64
#  10  Jatim        516 non-null    int64
#  11  Kalbar       516 non-null    int64
#  12  Kaltim       516 non-null    int64
#  13  Kalteng      516 non-null    int64
#  14  Kalsel       516 non-null    int64
#  15  Kaltara      516 non-null    int64
#  16  Kep Riau     516 non-null    int64
#  17  NTB          516 non-null    int64
# ...

# %%
dfc19.describe()
# Out:
#                Bali         Banten         Babel      Bengkulu            DIY  \
# count    516.000000     516.000000    516.000000    516.000000     516.000000
# mean   22600.257752   24425.662791   6694.848837   3887.271318   22098.600775
# std    22348.315184   28892.297923   9633.491224   4731.974946   30564.166024
# min        1.000000      17.000000      0.000000      0.000000       3.000000
# 25%     3100.000000    1722.750000    185.750000    198.750000     531.750000
# 50%    13933.500000   13138.000000   1019.000000   1832.500000    6018.000000
# 75%    41310.750000   44690.750000  10001.750000   5698.750000   35058.500000
# max    96027.000000  124661.000000  41946.000000  21361.000000  138458.000000
#
#              Jakarta         Jambi          Jabar         Jateng  \
# count     516.000000    516.000000     516.000000     516.000000
# mean   223194.802326   4416.653101  142498.550388   99971.782946
# std    229107.148678   5573.402440  170638.506772  108584.703840
# ...

# %%
dfc19.corr()
# Out:
#                Bali    Banten     Babel  Bengkulu       DIY   Jakarta  \
# Bali       1.000000  0.978113  0.957688  0.972744  0.957761  0.990620
# Banten     0.978113  1.000000  0.980216  0.993760  0.992214  0.981194
# Babel      0.957688  0.980216  1.000000  0.983197  0.986595  0.958940
# Bengkulu   0.972744  0.993760  0.983197  1.000000  0.993649  0.979186
# DIY        0.957761  0.992214  0.986595  0.993649  1.000000  0.967944
# Jakarta    0.990620  0.981194  0.958940  0.979186  0.967944  1.000000
# Jambi      0.971458  0.991364  0.991634  0.997243  0.993550  0.978083
# Jabar      0.987465  0.989623  0.982768  0.987001  0.983708  0.993096
# Jateng     0.992803  0.986672  0.969747  0.987950  0.976701  0.997035
# Jatim      0.990135  0.983181  0.947575  0.980715  0.966039  0.987965
# Kalbar     0.939378  0.981773  0.987651  0.987762  0.992908  0.950980
# Kaltim     0.998154  0.973570  0.950429  0.968526  0.952583  0.991568
# ...

# %%
dfapi = pd.read_json("https://api.coindesk.com/v1/bpi/currentprice.json")

# %%
dfapi
# Out:
#                                  time  \
# updated     Aug 18, 2021 07:10:00 UTC
# updatedISO  2021-08-18T07:10:00+00:00
# updateduk   Aug 18, 2021 at 08:10 BST
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# ...

# %%
lst_cols = ['No', 'Kode Saham', 'Nama Perusahaan','Sebelumnya', 'Open Price', 'Tertinggi', 'Terendah', 'Penutupan', 'Selisih', 'Volume', 'Nilai']

# %%
saham = pd.read_excel("Ringkasan Saham-20210816.xlsx",skiprows=1,usecols=lst_cols)
saham
# Out:
#       No Kode Saham                 Nama Perusahaan  Sebelumnya  Open Price  \
# 0      1       AALI         Astra Agro Lestari Tbk.        8475           0
# 1      2       ABBA               Mahaka Media Tbk.         496           0
# 2      3       ABDA    Asuransi Bina Dana Arta Tbk.        6950           0
# 3      4       ABMM              ABM Investama Tbk.        1490           0
# 4      5       ACES     Ace Hardware Indonesia Tbk.        1455        1485
# ..   ...        ...                             ...         ...         ...
# 738  739       YULE  Yulie Sekuritas Indonesia Tbk.         444           0
# 739  740       ZBRA             Zebra Nusantara Tbk        1050           0
# 740  741       ZINC          Kapuas Prima Coal Tbk.         136           0
# 741  742       ZONE              Mega Perintis Tbk.         390           0
# 742  743       ZYRX    Zyrexindo Mandiri Buana Tbk.         650           0
#
# ...

# %%
saham.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 743 entries, 0 to 742
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   No               743 non-null    int64
#  1   Kode Saham       743 non-null    object
#  2   Nama Perusahaan  743 non-null    object
#  3   Sebelumnya       743 non-null    int64
#  4   Open Price       743 non-null    int64
#  5   Tertinggi        743 non-null    int64
#  6   Terendah         743 non-null    int64
#  7   Penutupan        743 non-null    int64
#  8   Selisih          743 non-null    int64
#  9   Volume           743 non-null    int64
#  10  Nilai            743 non-null    int64
# dtypes: int64(9), object(2)
# memory usage: 64.0+ KB

# %%
new_df = saham.copy()

# %%
new_df['Persentase'] = saham['Selisih']/saham['Sebelumnya']*100
new_df.head()
# Out:
#    No Kode Saham               Nama Perusahaan  Sebelumnya  Open Price  \
# 0   1       AALI       Astra Agro Lestari Tbk.        8475           0
# 1   2       ABBA             Mahaka Media Tbk.         496           0
# 2   3       ABDA  Asuransi Bina Dana Arta Tbk.        6950           0
# 3   4       ABMM            ABM Investama Tbk.        1490           0
# 4   5       ACES   Ace Hardware Indonesia Tbk.        1455        1485
#
#    Tertinggi  Terendah  Penutupan  Selisih     Volume        Nilai  Persentase
# 0       8550      8350       8425      -50    1232300  10373710000   -0.589971
# 1        585       496        510       14  139331300  74690535700    2.822581
# 2          0         0       6950        0          0            0    0.000000
# 3       1515      1390       1390     -100     305600    440736500   -6.711409
# 4       1535      1460       1500       45   15861300  23766636500    3.092784

# %%
new_df.corr()
# Out:
#                   No  Sebelumnya  Open Price  Tertinggi  Terendah  Penutupan  \
# No          1.000000   -0.025174   -0.019388  -0.044321 -0.044072  -0.024584
# Sebelumnya -0.025174    1.000000    0.525238   0.897748  0.898909   0.999368
# Open Price -0.019388    0.525238    1.000000   0.587624  0.593091   0.534878
# Tertinggi  -0.044321    0.897748    0.587624   1.000000  0.998796   0.893525
# Terendah   -0.044072    0.898909    0.593091   0.998796  1.000000   0.894465
# Penutupan  -0.024584    0.999368    0.534878   0.893525  0.894465   1.000000
# Selisih     0.027389   -0.553500   -0.057128  -0.582519 -0.588338  -0.523538
# Volume     -0.067990   -0.046439   -0.011933  -0.040508 -0.040602  -0.047065
# Nilai      -0.135317    0.157310    0.257129   0.187776  0.187118   0.159757
# Persentase  0.062275   -0.045004   -0.001974  -0.047282 -0.049549  -0.035408
#
#              Selisih    Volume     Nilai  Persentase
# No          0.027389 -0.067990 -0.135317    0.062275
# ...

# %%
new_df_df["Persentase"].corr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-a774c395569d> in <module>
# ----> 1 new_df["Persentase"].corr()
#
# TypeError: corr() missing 1 required positional argument: 'other'
